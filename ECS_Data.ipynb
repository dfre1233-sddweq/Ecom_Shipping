# %%
from dotenv import load_dotenv

print(load_dotenv())
# Out:
# False

# %%
# !kaggle datasets download prachi13/customer-analytics
# Out:
# Dataset URL: https://www.kaggle.com/datasets/prachi13/customer-analytics
# License(s): other
# Downloading customer-analytics.zip to c:\Users\User\github\DataScience\Ecom_Shipping
#   0%|          | 0.00/121k [00:00<?, ?B/s]
# 100%|██████████| 121k/121k [00:00<00:00, 80.8MB/s]

# %%
import os
import zipfile

HOME = os.getcwd()

zip_file_path = os.path.join(HOME,'customer-analytics.zip')
extract_to_path = os.path.join(HOME,'data','titanic')

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)
    print(f"압축 해제 완료: {extract_to_path}")
# 해제된 파일 목록 확인
print("현재 폴더 파일 목록:", os.listdir(extract_to_path))
# Out:
# 압축 해제 완료: c:\Users\User\github\DataScience\Ecom_Shipping\data\titanic
# 현재 폴더 파일 목록: ['Train.csv']

# %% [markdown]
# 데이터셋 불러오기

# %%
import pandas as pd
HOME = os.getcwd()

df_csv= os.path.join(extract_to_path,'train.csv')

df = pd.read_csv(df_csv)

df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1
